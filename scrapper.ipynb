# %%
BASE_URL = "https://www.otodom.pl"
SEARCH_URL = BASE_URL + "/pl/wyniki/sprzedaz/mieszkanie/malopolskie/krakow/krakow/krakow?viewType=listing&page="
ulr = SEARCH_URL + "1"
print(ulr)
# Out:
# https://www.otodom.pl/pl/wyniki/sprzedaz/mieszkanie/malopolskie/krakow/krakow/krakow?viewType=listing&page=1

# %%
import requests
from bs4 import BeautifulSoup

def load_page(url: str) -> BeautifulSoup:
    res = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'html.parser')
    return soup

def get_links_for_search_page(n: int) -> list[str]:
    url = SEARCH_URL + str(n)
    soup = load_page(url)
    links = [BASE_URL + a['href'] for a in soup.find_all('a', attrs={'data-cy': 'listing-item-link'})]
    return links

# %%
links = get_links_for_search_page(1)
links[0]
# Out:
# 'https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-65m2-ogrodek-bezposrednio-ID4ulBE'

# %%
def extract_data(url: str, soup: BeautifulSoup):
    print(f"Extracting data from {url}")
    slug = url.split('/')[-1] # this is unique identifier which we can use as primary key
    name = soup.find('h1', attrs={'data-cy': 'adPageAdTitle'}).text
    price = soup.find('strong', attrs={'aria-label': 'Cena'}).text
    info = soup.find_all('div', attrs={'class': 'css-1ftqasz'})
    area = info[0].text
    rooms = info[1].text
    print(f"Extracted data: {name}, {price}, {area}, {rooms}")
    
    info_table = soup.find('div', {'class': 'css-t7cajz e15n0fyo1'}).parent
    info_table = [element for element in info_table.children if element.name == 'div']
    cols = ['heating', 'floor', 'rent', 'state', 'market', 'ownership', 'available', 'ad_type', 'extra_info']
    data = {col: info_table[idx].text for col, idx in zip(cols, range(0, 18, 2))}
    print(f"Data from table: {data}")

    data.update({'slug': slug, 'price': price, 'name': name, 'area': area, 'rooms': rooms})
    return data

# %%
import pandas as pd

def get_one_search_page(n: int) -> pd.DataFrame:
    links = get_links_for_search_page(n)
    df = pd.DataFrame()
    data_list = []
    for link in links:
        print(f"Checking {link}")
        soup = load_page(link)
        data = extract_data(link, soup)
        data_list.append(data)
    df = pd.concat([df, pd.DataFrame(data_list)], ignore_index=True)
    df.set_index('slug', inplace=True)
    return df

# %%
def get_n_pages(n: int, offset:int=0) -> pd.DataFrame:
    df = pd.DataFrame()
    for i in range(offset, n):
        df = pd.concat([df, get_one_search_page(i)], ignore_index=False)
    return df

# %%
df = get_n_pages(1)
# Out:
# Checking https://www.otodom.pl/pl/oferta/krakow-krowodrza-wroclawska-52a-kawalerka-ID4uISs
# Extracting data from https://www.otodom.pl/pl/oferta/krakow-krowodrza-wroclawska-52a-kawalerka-ID4uISs
# Extracted data: Kraków/Krowodrza/Wrocławska 52A/kawalerka, 339 000 zł, 17.01m², 1 pokój
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = get_n_pages(1)
#
# Cell In[18], line 4, in get_n_pages(n, offset)
#       2 df = pd.DataFrame()
#       3 for i in range(offset, n):
# ----> 4     df = pd.concat([df, get_one_search_page(i)], ignore_index=False)
#       5 return df
#
# Cell In[14], line 10, in get_one_search_page(n)
#       8     print(f"Checking {link}")
#       9     soup = load_page(link)
# ---> 10     data = extract_data(link, soup)
#      11     data_list.append(data)
#      12 df = pd.concat([df, pd.DataFrame(data_list)], ignore_index=True)
#
# Cell In[20], line 11, in extract_data(url, soup)
#       8 rooms = info[1].text
#       9 print(f"Extracted data: {name}, {price}, {area}, {rooms}")
# ---> 11 info_table = soup.find('div', {'class': 'css-t7cajz e15n0fyo1'}).parent
#      12 info_table = [element for element in info_table.children if element.name == 'div']
#      13 cols = ['heating', 'floor', 'rent', 'state', 'market', 'ownership', 'available', 'ad_type', 'extra_info']
#
# AttributeError: 'NoneType' object has no attribute 'parent'

# %%
# Check what we've got - random 5 rows
print(df.shape)
df.sample(5)
# Out:
# (69, 13)
#                                                                        heating  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7                Ogrzewanie:miejskie
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Ogrzewanie:brak informacji
# green-apartments-2-0-petrazyckiego-nowa-inwesty...           Ogrzewanie:gazowe
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Ogrzewanie:brak informacji
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Ogrzewanie:brak informacji
#
#                                                               floor  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Piętro:parter/9
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ             Piętro:1/7
# green-apartments-2-0-petrazyckiego-nowa-inwesty...       Piętro:1/2
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Piętro:parter/1
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh               Piętro:8/10
#
#                                                                       rent  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Czynsz:brak informacji
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Czynsz:brak informacji
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Czynsz:brak informacji
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Czynsz:brak informacji
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Czynsz:brak informacji
#
#                                                                               state  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Stan wykończenia:do wykończenia
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Stan wykończenia:do wykończenia
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Stan wykończenia:do wykończenia
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Stan wykończenia:do wykończenia
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Stan wykończenia:do wykończenia
#
#                                                              market  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Rynek:pierwotny
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Rynek:pierwotny
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Rynek:pierwotny
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Rynek:pierwotny
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Rynek:pierwotny
#
#                                                                          ownership  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Forma własności:pełna własność
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Forma własności:pełna własność
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Forma własności:pełna własność
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Forma własności:pełna własność
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Forma własności:pełna własność
#
#                                                                       available  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7              Dostępne od:2025-06-30
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ             Dostępne od:2025-11-15
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Dostępne od:brak informacji
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...       Dostępne od:2026-05-15
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh                Dostępne od:2025-05-05
#
#                                                                           ad_type  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Typ ogłoszeniodawcy:deweloper
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Typ ogłoszeniodawcy:deweloper
# green-apartments-2-0-petrazyckiego-nowa-inwesty...   Typ ogłoszeniodawcy:prywatny
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Typ ogłoszeniodawcy:deweloper
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Typ ogłoszeniodawcy:deweloper
#
#                                                                                            extra_info  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         Informacje dodatkowe:balkon garaż/miejsce park...
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ        Informacje dodatkowe:balkon garaż/miejsce park...
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Informacje dodatkowe:balkon garaż/miejsce park...
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Informacje dodatkowe:taras ogródek garaż/miejs...
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           Informacje dodatkowe:balkon garaż/miejsce park...
#
#                                                              price  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7             760 158 zł
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ          1 648 653 zł
# green-apartments-2-0-petrazyckiego-nowa-inwesty...      734 000 zł
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  Zapytaj o cenę
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh               861 000 zł
#
#                                                                                                  name  \
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7                 ul. Powstańców | mieszkanie 3-pok. | E 38
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ                   4-pokojowe mieszkanie 90m2 + 2 balkony
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  Green Apartments 2.0 Petrażyckiego NOWA INWEST...
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  4-pokojowe mieszkanie 146m2 + ogródek Bez Prow...
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh                         3-pokojowe mieszkanie 60m2 + balkon
#
#                                                        area     rooms
# slug
# ul-powstancow-mieszkanie-3-pok-e-38-ID4tLF7         60.33m²  3 pokoje
# 4-pokojowe-mieszkanie-90m2-2-balkony-ID4ulXQ         90.4m²  4 pokoje
# green-apartments-2-0-petrazyckiego-nowa-inwesty...  77.89m²  4 pokoje
# 4-pokojowe-mieszkanie-146m2-ogrodek-bez-prowizj...  146.8m²  4 pokoje
# 3-pokojowe-mieszkanie-60m2-balkon-ID4uomh           60.18m²  3 pokoje

# %%
df.to_csv('otodom.csv')
