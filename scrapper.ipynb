# %%
BASE_URL = "https://www.otodom.pl"
SEARCH_URL = BASE_URL + "/pl/wyniki/sprzedaz/mieszkanie/malopolskie/krakow/krakow/krakow?viewType=listing&page="
ulr = SEARCH_URL + "1"
print(ulr)
# Out:
# https://www.otodom.pl/pl/wyniki/sprzedaz/mieszkanie/malopolskie/krakow/krakow/krakow?viewType=listing&page=1

# %%
import requests
from bs4 import BeautifulSoup

def load_page(url: str) -> BeautifulSoup:
    res = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'html.parser')
    return soup

def get_links_for_search_page(n: int) -> list[str]:
    url = SEARCH_URL + str(n)
    soup = load_page(url)
    links = [BASE_URL + a['href'] for a in soup.find_all('a', attrs={'data-cy': 'listing-item-link'})]
    return links

# %%
links = get_links_for_search_page(1)
links[0]
# Out:
# 'https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-38m2-balkon-bez-prowizji-ID4ul5O'

# %%
def extract_data(url: str, soup: BeautifulSoup):
    slug = url.split('/')[-1] # this is unique identifier which we can use as primary key
    name = soup.find('h1', attrs={'data-cy': 'adPageAdTitle'}).text
    price = soup.find('strong', attrs={'aria-label': 'Cena'}).text
    info = soup.find_all('div', attrs={'class': 'css-1ftqasz'})
    area = info[0].text
    rooms = info[1].text
    
    info_table = soup.find('div', {'class': 'css-t7cajz e16p81cp1'}).parent
    info_table = [element for element in info_table.children if element.name == 'div']
    cols = ['heating', 'floor', 'rent', 'state', 'market', 'ownership', 'available', 'ad_type', 'extra_info']
    data = {col: info_table[idx].text for col, idx in zip(cols, range(0, 18, 2))}

    data.update({'slug': slug, 'price': price, 'name': name, 'area': area, 'rooms': rooms})
    return data

# %%
import pandas as pd

def get_one_search_page(n: int) -> pd.DataFrame:
    links = get_links_for_search_page(n)
    df = pd.DataFrame()
    data_list = []
    for link in links:
        print(f"Checking {link}")
        soup = load_page(link)
        data = extract_data(link, soup)
        data_list.append(data)
    df = pd.concat([df, pd.DataFrame(data_list)], ignore_index=True)
    df.set_index('slug', inplace=True)
    return df

# %%
def get_n_pages(n: int, offset:int=0) -> pd.DataFrame:
    df = pd.DataFrame()
    for i in range(offset, n):
        df = pd.concat([df, get_one_search_page(i)], ignore_index=False)
    return df

# %%
df = get_n_pages(1)
# Out:
# Checking https://www.otodom.pl/pl/oferta/duzy-ogrodek-120m2-mieszkanie-44-42m2-ID4uJ2T
# Checking https://www.otodom.pl/pl/oferta/2-pokoje-na-podgorzu-wielicka-ID4tgDZ
# Checking https://www.otodom.pl/pl/oferta/kawalerka-po-generalnym-remoncie-ID4tHWr
# Checking https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-ID4t4xf
# Checking https://www.otodom.pl/pl/oferta/5-pokojowe-mieszkanie-162m2-taras-ID4uhOa
# (30, 13)
#                                                                        heating  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...         Ogrzewanie:miejskie
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...         Ogrzewanie:miejskie
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...           Ogrzewanie:gazowe
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...  Ogrzewanie:brak informacji
# 2poziomowy-apartament-panoramiczny-widok-centru...           Ogrzewanie:gazowe
#
#                                                          floor  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...    Piętro:1
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...  Piętro:5/6
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  Piętro:1/4
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...  Piętro:2/5
# 2poziomowy-apartament-panoramiczny-widok-centru...  Piętro:4/4
#
#                                                                       rent  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...          Czynsz:650 zł
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...  Czynsz:brak informacji
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...        Czynsz:1 184 zł
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...  Czynsz:brak informacji
# 2poziomowy-apartament-panoramiczny-widok-centru...  Czynsz:brak informacji
#
#                                                                                state  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...  Stan wykończenia:do zamieszkania
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...   Stan wykończenia:do wykończenia
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  Stan wykończenia:do zamieszkania
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...   Stan wykończenia:do wykończenia
# 2poziomowy-apartament-panoramiczny-widok-centru...   Stan wykończenia:do wykończenia
#
#                                                              market  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...     Rynek:wtórny
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...  Rynek:pierwotny
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...     Rynek:wtórny
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...  Rynek:pierwotny
# 2poziomowy-apartament-panoramiczny-widok-centru...  Rynek:pierwotny
#
#                                                                          ownership  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...  Forma własności:pełna własność
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...  Forma własności:pełna własność
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  Forma własności:pełna własność
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...  Forma własności:pełna własność
# 2poziomowy-apartament-panoramiczny-widok-centru...  Forma własności:pełna własność
#
#                                                                       available  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...  Dostępne od:brak informacji
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...  Dostępne od:brak informacji
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...       Dostępne od:2024-11-06
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...       Dostępne od:2024-06-06
# 2poziomowy-apartament-panoramiczny-widok-centru...  Dostępne od:brak informacji
#
#                                                                                      ad_type  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...              Typ ogłoszeniodawcy:prywatny
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...  Typ ogłoszeniodawcy:biuro nieruchomości
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  Typ ogłoszeniodawcy:biuro nieruchomości
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...             Typ ogłoszeniodawcy:deweloper
# 2poziomowy-apartament-panoramiczny-widok-centru...  Typ ogłoszeniodawcy:biuro nieruchomości
#
#                                                                                            extra_info  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...                        Informacje dodatkowe:balkon
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...               Informacje dodatkowe:brak informacji
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...                Informacje dodatkowe:balkon piwnica
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...  Informacje dodatkowe:balkon garaż/miejsce park...
# 2poziomowy-apartament-panoramiczny-widok-centru...               Informacje dodatkowe:brak informacji
#
#                                                            price  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...  1 117 000 zł
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...    575 960 zł
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  2 450 000 zł
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...    861 010 zł
# 2poziomowy-apartament-panoramiczny-widok-centru...  1 739 475 zł
#
#                                                                                                  name  \
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...      Sprzedam, apartament w kamienicy po renowacji
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...   studio | funkcjonalny układ | panoramiczny widok
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  6- Pokojowy Apartament Inwestycyjny I Słowackiego
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...   3-pokojowe mieszkanie 57m2 + balkon Bezpośrednio
# 2poziomowy-apartament-panoramiczny-widok-centru...  2poziomowy apartament|panoramiczny widok| centrum
#
#                                                         area     rooms
# slug
# sprzedam-apartament-w-kamienicy-po-renowacji-ID...   42.58m²  2 pokoje
# studio-funkcjonalny-uklad-panoramiczny-widok-ID...   26.18m²   1 pokój
# 6-pokojowy-apartament-inwestycyjny-i-slowackieg...  163.35m²   6 pokoi
# 3-pokojowe-mieszkanie-57m2-balkon-bezposrednio-...   57.21m²  3 pokoje
# 2poziomowy-apartament-panoramiczny-widok-centru...   77.31m²  4 pokoje

# %%
df.to_csv('otodom.csv')
